# %%
# Importing libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # EXTRACTING AND FILTERING THE DATASETS
#
# First step is to extract one of the datasets used for this project from a geopackage database

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\danie\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.24 in c:\users\danie\anaconda3\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\danie\anaconda3\lib\site-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in c:\users\danie\anaconda3\lib\site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\danie\anaconda3\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\danie\anaconda3\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\danie\anaconda3\lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\danie\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danie\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\danie\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\danie\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\danie\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

data = gpd.read_file("prodes_amazonia_nb2.gpkg")
# Out:
# C:\Users\danie\anaconda3\Lib\site-packages\pyogrio\geopandas.py:382: UserWarning: More than one layer found in 'prodes_amazonia_nb2.gpkg': 'accumulated_deforestation_2000_nf_biome' (default), 'no_forest_biome', 'residual_biome', 'yearly_deforestation_biome', 'hydrography_biome', 'accumulated_deforestation_2007_biome', 'yearly_deforestation_nf_biome', 'hydrography_nf_biome', 'residual_nf_biome', 'yearly_deforestation_smaller_than_625ha_biome'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %%
data = gpd.read_file("prodes_amazonia_nb2.gpkg", layer="yearly_deforestation_nf_biome")

# %%
df = data.drop(columns="geometry")
df.to_csv("prodes_amazon_legal.csv", index=False)

# %% [markdown]
# Secondly, I filtered the brazil beef dataset to extract only the region that we are focusing for this project

# %%
livestock = pd.read_csv("brazil_beef_v2_2_1.csv")

# %%
livestock['biome'].unique()
# Out:
# array(['AMAZONIA', 'CAATINGA', 'CERRADO', 'MATA ATLANTICA', 'PAMPA',
#        'PANTANAL', 'UNKNOWN'], dtype=object)

# %%
livestock = livestock[
    livestock['biome'].str.strip().str.upper() == 'AMAZONIA'
]

# %%
livestock.to_csv("beef_amazon.csv", index=False)

# %% [markdown]
# # EDA( EXPLORATORY DATA ANALYSIS)

# %% [markdown]
# ## IMPORTING THE DATASETS

# %%
deforestation_df = pd.read_csv("prodes_amazon_legal.csv")
beef_df = pd.read_csv("beef_amazon.csv")
co2_df = pd.read_excel("inpe_EM_BRAmz_results.xlsx", sheet_name = "Com degradação", skiprows=10)

# %%
deforestation_df.head()
# Out:
#   state  path_row    main_class class_name  def_cloud  julian_day  image_date  \
# 0    MT     22871  desmatamento      d2023        0.0         259  2023-09-16
# 1    AP     22560  desmatamento      d2002        NaN         232  2002-08-20
# 2    MT     22871  desmatamento      d2008        NaN         230  2008-08-17
# 3    MT     21016  desmatamento      d2024        0.0         256  2024-09-12
# 4    AM     22962  desmatamento      d2004        NaN         290  2004-10-16
#
#    year   area_km  scene_id                   source   satellite sensor  \
# 0  2023  0.030756   10329.0  Amazonia - Nao Floresta  Sentinel-2    MSI
# 1  2002  5.214920       NaN                 Amazônia    LANDSAT8    OLI
# 2  2008  0.111416       NaN                 Amazônia    LANDSAT8    OLI
# 3  2024  0.013637   10610.0  Amazonia - Nao Floresta  Sentinel-2    MSI
# 4  2004  0.144495       NaN                 Amazônia    LANDSAT8    OLI
#
#                                    uuid
# 0  bd04328e-979a-4706-94e9-7b5a7ec2b15b
# 1  68272938-3419-462c-b112-101c1ba38c6b
# 2  84d395b0-999a-4319-854e-37f6370a7bae
# 3  cfc86599-70eb-4486-bea5-3186786b5039
# 4  809bafdc-4dfd-45f7-8cd8-7490795d3391

# %%
beef_df.head()
# Out:
#    year country_of_production     biome state_of_production  \
# 0  2011                BRAZIL  AMAZONIA                ACRE
# 1  2011                BRAZIL  AMAZONIA                ACRE
# 2  2011                BRAZIL  AMAZONIA                ACRE
# 3  2011                BRAZIL  AMAZONIA            AMAZONAS
# 4  2011                BRAZIL  AMAZONIA            AMAZONAS
#
#   state_of_production_trase_id municipality_of_production  \
# 0                        BR-12                     BUJARI
# 1                        BR-12                 RIO BRANCO
# 2                        BR-12           SENADOR GUIOMARD
# 3                        BR-13               BOCA DO ACRE
# 4                        BR-13                     LABREA
#
#   municipality_of_production_trase_id logistics_hub   product_type  \
# 0                          BR-1200138       UNKNOWN    BEEF OFFALS
# 1                          BR-1200401       UNKNOWN    BEEF OFFALS
# 2                          BR-1200450       UNKNOWN    BEEF OFFALS
# 3                          BR-1300706       UNKNOWN    BEEF OFFALS
# 4                          BR-1302405          JARU  BEEF BONELESS
#
#   port_of_export  ... country_of_destination       economic_bloc  \
# 0         SANTOS  ...      CHINA (HONG KONG)   CHINA (HONG KONG)
# 1         SANTOS  ...      CHINA (HONG KONG)   CHINA (HONG KONG)
# 2         SANTOS  ...      CHINA (HONG KONG)   CHINA (HONG KONG)
# 3         SANTOS  ...      CHINA (HONG KONG)   CHINA (HONG KONG)
# 4         ITAJAA  ...     RUSSIAN FEDERATION  RUSSIAN FEDERATION
#
#   country_of_production_trase_id country_of_destination_trase_id  \
# 0                             BR                              HK
# 1                             BR                              HK
# 2                             BR                              HK
# 3                             BR                              HK
# 4                             BR                              RU
#
#   cattle_deforestation_5_year_total_exposure  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   co2_gross_emissions_cattle_deforestation_5_year_total_exposure  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   co2_net_emissions_cattle_deforestation_5_year_total_exposure land_use  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
#
#       volume           fob
# 0   0.689217   2763.220500
# 1   0.975922   3912.684851
# 2   0.697649   2797.025472
# 3  11.786114  39216.614533
# 4   1.119702   3395.156400
#
# [5 rows x 26 columns]

# %%
co2_df
# Out:
#     Year  D_AreaAcc   D_Area  DEGRAD_Area  -  VR_CO2_1stOrder  \
# 0   1960     842754   842754            0  -              411
# 1   1961    1685508   842754            0  -              411
# 2   1962    2528262   842754            0  -              411
# 3   1963    3371016   842754            0  -              411
# 4   1964    4213770   842754            0  -              411
# ..   ...        ...      ...          ... ..              ...
# 56  2016   65054606   789300      2725626  -              415
# 57  2017   65749320   694713      2223562  -              359
# 58  2018   66502905   753584      2331173  -              393
# 59  2019   67515838  1012933       639826  -              541
# 60  2020   68624639  1108800       811941  -              582
#
#     VR_CO2_2ndOrder  SV_CO2Emission  SV_CO2Absorption -.1  DEGRAD_CO2Emission  \
# 0               133               0                 0   -                   0
# 1               222               0                 0   -                   0
# 2               276               0                 0   -                   0
# 3               311               0                -2   -                   0
# 4               334               0                -4   -                   0
# ..              ...             ...               ...  ..                 ...
# 56              373             127              -174   -                 691
# 57              371             131              -176   -                 443
# 58              381             134              -178   -                 394
# 59              432             136              -181   -                  99
# 60              478             138              -185   -                 129
#
#     DEGRAD_CO2Absorption -.2  NET_1st_Order  NET_2nd_Order
# 0                      0   -            411            133
# 1                      0   -            411            222
# 2                      0   -            411            276
# 3                      0   -            409            309
# 4                      0   -            407            329
# ..                   ...  ..            ...            ...
# 56                  -179   -            880            838
# 57                  -239   -            518            531
# 58                  -242   -            502            489
# 59                  -245   -            351            241
# 60                  -193   -            471            367
#
# [61 rows x 15 columns]

# %%
deforestation_df['year'].unique()
# Out:
# array([2023, 2002, 2008, 2024, 2004, 2018, 2020, 2021, 2006, 2016, 2019,
#        2014, 2022, 2013, 2010], dtype=int64)

# %%
beef_df['year'].unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2019, 2020, 2021, 2022,
#        2023], dtype=int64)

# %%
co2_df['Year'].unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
deforestation_df.dtypes
# Out:
# state          object
# path_row        int64
# main_class     object
# class_name     object
# def_cloud     float64
# julian_day      int64
# image_date     object
# year            int64
# area_km       float64
# scene_id      float64
# source         object
# satellite      object
# sensor         object
# uuid           object
# dtype: object

# %%
beef_df.dtypes
# Out:
# year                                                                int64
# country_of_production                                              object
# biome                                                              object
# state_of_production                                                object
# state_of_production_trase_id                                       object
# municipality_of_production                                         object
# municipality_of_production_trase_id                                object
# logistics_hub                                                      object
# product_type                                                       object
# port_of_export                                                     object
# exporter                                                           object
# exporter_group                                                     object
# zero_deforestation_brazil_beef                                     object
# forest_500_beef                                                    object
# importer                                                           object
# importer_group                                                     object
# country_of_destination                                             object
# economic_bloc                                                      object
# country_of_production_trase_id                                     object
# country_of_destination_trase_id                                    object
# cattle_deforestation_5_year_total_exposure                        float64
# co2_gross_emissions_cattle_deforestation_5_year_total_exposure    float64
# co2_net_emissions_cattle_deforestation_5_year_total_exposure      float64
# land_use                                                          float64
# volume                                                            float64
# fob                                                               float64
# dtype: object

# %%
co2_df.dtypes
# Out:
# Year                     int64
# D_AreaAcc                int64
# D_Area                   int64
# DEGRAD_Area              int64
# -                       object
# VR_CO2_1stOrder          int64
# VR_CO2_2ndOrder          int64
# SV_CO2Emission           int64
# SV_CO2Absorption         int64
# -.1                     object
# DEGRAD_CO2Emission       int64
# DEGRAD_CO2Absorption     int64
# -.2                     object
# NET_1st_Order            int64
# NET_2nd_Order            int64
# dtype: object

# %%
deforestation_df.shape
# Out:
# (117177, 14)

# %%
beef_df.shape
# Out:
# (839727, 26)

# %%
co2_df.shape
# Out:
# (61, 15)

# %%
deforestation_df.duplicated().sum()
# Out:
# 0

# %%
co2_df.duplicated().sum()
# Out:
# 0

# %%
deforestation_df.isnull().sum()
# Out:
# state              0
# path_row           0
# main_class         0
# class_name         0
# def_cloud     107965
# julian_day         0
# image_date         0
# year               0
# area_km            0
# scene_id      107988
# source             0
# satellite          0
# sensor             0
# uuid               0
# dtype: int64

# %%
beef_df.isnull().sum()
# Out:
# year                                                                   0
# country_of_production                                                  0
# biome                                                                  0
# state_of_production                                                    0
# state_of_production_trase_id                                           0
# municipality_of_production                                             0
# municipality_of_production_trase_id                                    0
# logistics_hub                                                          0
# product_type                                                           0
# port_of_export                                                         0
# exporter                                                               0
# exporter_group                                                         0
# zero_deforestation_brazil_beef                                         0
# forest_500_beef                                                        0
# importer                                                               0
# importer_group                                                         0
# country_of_destination                                                 0
# economic_bloc                                                          0
# country_of_production_trase_id                                         0
# country_of_destination_trase_id                                        0
# cattle_deforestation_5_year_total_exposure                        209124
# co2_gross_emissions_cattle_deforestation_5_year_total_exposure    209124
# co2_net_emissions_cattle_deforestation_5_year_total_exposure      209124
# land_use                                                           31459
# volume                                                                 0
# fob                                                                    0
# dtype: int64

# %%
co2_df.isnull().sum()
# Out:
# Year                    0
# D_AreaAcc               0
# D_Area                  0
# DEGRAD_Area             0
# -                       0
# VR_CO2_1stOrder         0
# VR_CO2_2ndOrder         0
# SV_CO2Emission          0
# SV_CO2Absorption        0
# -.1                     0
# DEGRAD_CO2Emission      0
# DEGRAD_CO2Absorption    0
# -.2                     0
# NET_1st_Order           0
# NET_2nd_Order           0
# dtype: int64

# %%
deforestation_df.describe()
# Out:
#             path_row  def_cloud     julian_day           year        area_km  \
# count  117177.000000     9212.0  117177.000000  117177.000000  117177.000000
# mean    22604.030245        0.0     244.723461    2011.732507       0.148804
# std      2173.674931        0.0      41.729522       7.432707       0.622272
# min       158.000000        0.0      15.000000    2002.000000       0.000020
# 25%     22567.000000        0.0     224.000000    2004.000000       0.019603
# 50%     22871.000000        0.0     240.000000    2010.000000       0.038777
# 75%     23068.000000        0.0     270.000000    2019.000000       0.094432
# max     33008.000000        0.0     361.000000    2024.000000      53.043873
#
#            scene_id
# count   9189.000000
# mean   10451.843073
# std      154.620532
# min    10242.000000
# 25%    10319.000000
# 50%    10424.000000
# 75%    10523.000000
# max    10775.000000

# %%
beef_df.describe()
# Out:
#                 year  cattle_deforestation_5_year_total_exposure  \
# count  839727.000000                               630603.000000
# mean     2017.910960                                    3.152878
# std         3.810633                                   32.922416
# min      2011.000000                                    0.000000
# 25%      2015.000000                                    0.118720
# 50%      2019.000000                                    0.440201
# 75%      2021.000000                                    1.526267
# max      2023.000000                                 8432.792534
#
#        co2_gross_emissions_cattle_deforestation_5_year_total_exposure  \
# count                                       6.306030e+05
# mean                                        1.431608e+03
# std                                         1.658885e+04
# min                                         0.000000e+00
# 25%                                         4.290230e+01
# 50%                                         1.697448e+02
# 75%                                         6.197420e+02
# max                                         4.252106e+06
#
#        co2_net_emissions_cattle_deforestation_5_year_total_exposure  \
# count                                       6.306030e+05
# mean                                        1.319155e+03
# std                                         1.541352e+04
# min                                         0.000000e+00
# 25%                                         3.834555e+01
# 50%                                         1.537368e+02
# 75%                                         5.642000e+02
# max                                         3.972162e+06
#
#             land_use         volume           fob
# count  808268.000000  839727.000000  8.397270e+05
# mean      114.752244       7.560965  2.547733e+04
# std       548.265643      34.026620  1.205131e+05
# min         0.000000       0.299620  1.483560e+02
# 25%        13.955774       1.014637  3.241834e+03
# 50%        28.407606       1.938585  6.313568e+03
# 75%        73.893583       4.911512  1.625017e+04
# max    100000.437286    4278.000019  1.586512e+07

# %%
co2_df.describe()
# Out:
#               Year     D_AreaAcc        D_Area   DEGRAD_Area  VR_CO2_1stOrder  \
# count    61.000000  6.100000e+01  6.100000e+01  6.100000e+01        61.000000
# mean   1990.000000  3.746415e+07  1.324505e+06  4.035045e+05       653.622951
# std      17.752934  2.365221e+07  6.324252e+05  7.129856e+05       302.902634
# min    1960.000000  8.427540e+05  4.571000e+05  0.000000e+00       234.000000
# 25%    1975.000000  1.348406e+07  8.427540e+05  0.000000e+00       411.000000
# 50%    1990.000000  4.030233e+07  1.103000e+06  1.558720e+05       541.000000
# 75%    2005.000000  6.107624e+07  1.822600e+06  1.558720e+05       888.000000
# max    2020.000000  6.972315e+07  2.905900e+06  2.741165e+06      1416.000000
#
#        VR_CO2_2ndOrder  SV_CO2Emission  SV_CO2Absorption  DEGRAD_CO2Emission  \
# count        61.000000       61.000000         61.000000            61.00000
# mean        616.196721       48.704918        -86.032787            81.52459
# std         260.263701       45.004201         61.896410           146.53755
# min         133.000000        0.000000       -185.000000             0.00000
# 25%         381.000000        7.000000       -143.000000             0.00000
# 50%         603.000000       39.000000        -81.000000            34.00000
# 75%         844.000000       83.000000        -28.000000            34.00000
# max        1107.000000      138.000000          0.000000           691.00000
#
#        DEGRAD_CO2Absorption  NET_1st_Order  NET_2nd_Order
# count             61.000000      61.000000      61.000000
# mean             -54.590164     643.163934     605.688525
# std               84.977718     308.937004     270.875097
# min             -245.000000     108.000000     133.000000
# 25%              -31.000000     396.000000     366.000000
# 50%              -18.000000     550.000000     667.000000
# 75%                0.000000     880.000000     853.000000
# max                0.000000    1380.000000    1053.000000

# %%
deforestation_df.hist(figsize=(20,15))
plt.tight_layout()
plt.show()

# %%
beef_df.hist(figsize=(20,15))
plt.tight_layout()
plt.show()

# %%
co2_df.hist(figsize=(20,15))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
deforestation_df.boxplot(column=['area_km'])
plt.title('Area deforested by km')
plt.show()

# %%
plt.figure(figsize=(8,6))
beef_df.boxplot(column=['volume', 'fob', 'cattle_deforestation_5_year_total_exposure','co2_gross_emissions_cattle_deforestation_5_year_total_exposure','co2_net_emissions_cattle_deforestation_5_year_total_exposure','land_use' ])
plt.xticks(rotation=45, ha='right')
plt.title('Boxplot of Beef Dataset Variables')
plt.show()

# %%
plt.figure(figsize=(8,6))
co2_df.boxplot(column=['NET_2nd_Order'])
plt.title('Total net CO₂ emissions including deforestation + degradation – absorption')
plt.show()
